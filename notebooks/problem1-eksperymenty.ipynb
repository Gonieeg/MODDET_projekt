# %% [markdown]
# Import funkcji

# %%
import sys
sys.path.append("../pipeline")
from funkcje import *
from problem1 import *

sim1 = Problem1()

# %% [markdown]
# ## Testy
#
# symuluj przyjmuje kolejno:
# - T - czas symulacji [s],
# - ht - krok,
# - n - rozmiar siatki (np. 1, 2),
# - temp_outside - temperatura zewnętrzna [$^\circ C$],
# - j - umiejscowienie grzejnika (co 1, od 2 do 20*n-1),
# - strategia - ustawienie grzałki grzejnika - 0, 1, 2, 4

# %% [markdown]
# 1. Testy czasu trwania symulacji
# T=?
# ht=1
# n=2
# temp_outside=0
# j, strategia = 0

# %%
T60 = sim1.symuluj(60, 1, 2, 0, 2, 0)
# Out:
# mean 0:  293.1500000000001
# mean 60:  293.01064974662836
# standard deviation:0.4085711672242998
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 T60 = sim1.symuluj(60, 1, 2, 0, 2, 0)
#
# File ~\PycharmProjects\MODDET_projekt\notebooks\../pipeline\problem1.py:147, in Problem1.symuluj(self, T, ht, n, temp_outside, j, strategia)
#     144 axs[1, 0].set_title(f'Wynik po {t} krokach')
#     145 fig.colorbar(im3, ax=axs[1, 0])
# --> 147 axs[1, 1].plot(range(t), Cel(zmianysredniej))
#     148 axs[1, 1].set_title('Średnia temperatura w czasie')
#     149 axs[1, 1].set_xlabel('krok czasu')
#
# File ~\PycharmProjects\MODDET_projekt\notebooks\../pipeline\funkcje.py:46, in Cel(Kel)
#      44 def Cel(Kel):
#      45   """Przekształca stopnie Kelvina na stopnie Celsjusza"""
# ---> 46   return Kel - 273.15
#
# TypeError: unsupported operand type(s) for -: 'list' and 'float'
