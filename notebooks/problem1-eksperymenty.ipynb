# %% [markdown]
# Import funkcji

# %%
import sys
sys.path.append("../pipeline")
from funkcje import *
from problem1 import *

sim1 = Problem1()

# %% [markdown]
# ## Testy
#
# *symuluj* przyjmuje kolejno:
# - T - czas symulacji [s],
# - ht - krok,
# - n - rozmiar siatki (np. 1, 2),
# - temp_outside - temperatura zewnętrzna [$^\circ C$],
# - j - umiejscowienie grzejnika (co 1, od 2 do 20*n-1),
# - strategia - ustawienie grzałki grzejnika - 0, 1, 2, 4

# %% [markdown]
# ### Testy czasu trwania symulacji
# T=?
# ht=1
# n=2
# temp_outside=0
# j, strategia = 0

# %%
# symulacja minuty
T60 = sim1.symuluj(60, 1, 2, 0, 2, 0)
# Out:
# mean 0:  293.1500000000001
# mean 60:  293.01064974662836
# standard deviation:0.4085711672242998

# %%
# symulacja 10 minut
T600 = sim1.symuluj(600, 1, 2, 0, 2, 0)
# Out:
# mean 0:  293.1500000000001
# mean 600:  292.0481038207771
# standard deviation:2.3041764554712736

# %%
# symulacja 30 minut
T1800 = sim1.symuluj(1800, 1, 2, 0, 2, 0)
# Out:
# mean 0:  293.1500000000001
# mean 1800:  290.640559693932
# standard deviation:3.815079658843055

# %%
# symulacja 1 godziny
T3600 = sim1.symuluj(3600, 1, 2, 0, 2, 0)
# Out:
# mean 0:  293.1500000000001
# mean 3600:  289.17372556044336
# standard deviation:4.7491764864046875

# %%
# symulacja 3 godzin
T10800 = sim1.symuluj(10800, 1, 2, 0, 2, 0)
# Out:
# mean 0:  293.1500000000001
# mean 10800:  285.5990060297737
# standard deviation:5.581745891065318

# %% [markdown]
# ### Testy różnych temperatur zewnętrznych dla 30 minut
# T=1800
# ht=1
# n=2
# temp_outside=?
# j, strategia = 0

# %%
# -10 stopni
tempminus = sim1.symuluj(1800, 1, 2, -10, 2, 0)
# Out:
# mean 0:  293.1500000000001
# mean 1800:  289.3858395409969
# standard deviation:5.7226194882087285

# %%
# 0 stopni
T1800 # dorobic wykresy!!
# Out:
# array([0.47815781, 1.08650109, 1.62783227, ..., 1.62368381, 1.08459744,
#        0.47732004], shape=(1681,))

# %%
# 10 stopni
temp10 = sim1.symuluj(1800, 1, 2, 10, 2, 0)
# Out:
# mean 0:  293.1500000000001
# mean 1800:  291.89527984686583
# standard deviation:1.9075398294773782

# %%
# 20 stopni
temp20 = sim1.symuluj(1800, 1, 2, 20, 2, 0)
# Out:
# mean 0:  293.1500000000001
# mean 1800:  293.14999999992256
# standard deviation:5.995899954461861e-11

# %% [markdown]
# ### Testy strategii grzania dla grzejnika na środku pomieszczenia
# T=1800 # 30 min
# ht=1
# n=2
# temp_outside=?
# j = 20
# strategia = ?

# %%
# strategia 0 - grzejnik wyłączony
