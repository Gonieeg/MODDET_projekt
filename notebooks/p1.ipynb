# %% [markdown]
# Sprawdzam import klas

# %%
import sys
sys.path.append("../pipeline")
from p1 import ETCS

sim = ETCS()
sim.start(T=10, n=1, od=-1, do=1)
sim.ustaw_warunki(ht=1)
sim.symuluj()
sim.wykresy()
